# %%
import pandas as pd

# %%
train = pd.read_csv('train.csv')
train.shape
# Out:
# (891, 12)

# %%
test = pd.read_csv('test.csv')
test.shape
# Out:
# (418, 12)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
train.pivot_table('Survived',['Pclass','SibSp'])
# Out:
#               Survived
# Pclass SibSp
# 1      0      0.562044
#        1      0.746479
#        2      0.800000
#        3      0.666667
# 2      0      0.416667
#        1      0.581818
#        2      0.500000
#        3      1.000000
# 3      0      0.236467
#        1      0.325301
#        2      0.333333
#        3      0.083333
#        4      0.166667
#        5      0.000000
#        8      0.000000

# %%
test['Survived'] = (test['Sex'] == 'female' and (test['Pclass'] == "1" or test['Pclass'] == "2")) or (test['Sex'] == 'male' and (test['Pclass'] == "1" or test['Pclass'] == "2"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-f3a9d54d88cb> in <module>()
# ----> 1 test['Survived'] = (test['Sex'] == 'female' and (test['Pclass'] == "1" or test['Pclass'] == "2")) or (test['Sex'] == 'male' and (test['Pclass'] == "1" or test['Pclass'] == "2"))
#
# ~\Anaconda\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1571         raise ValueError("The truth value of a {0} is ambiguous. "
#    1572                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1573                          .format(self.__class__.__name__))
#    1574
#    1575     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
test['Survived'] = test['Survived'].astype(int)
test
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# 5            897         0       3
# 6            898         1       3
# 7            899         0       2
# 8            900         1       3
# 9            901         0       3
# 10           902         0       3
# 11           903         0       1
# 12           904         1       1
# 13           905         0       2
# 14           906         1       1
# 15           907         1       2
# 16           908         0       2
# 17           909         0       3
# 18           910         1       3
# 19           911         1       3
# 20           912         0       1
# 21           913         0       3
# 22           914         1       1
# 23           915         0       1
# 24           916         1       1
# ...

# %%
submission = test[['PassengerId','Survived']].copy()
submission = test['Survived'] = submission['Survived'].astype(int)

# %%
submission.head()
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    1
# Name: Survived, dtype: int32

# %%
# %mkdir submissions

# %%
submission.to_csv('submissions/submissions.csv',index=False)

# %%
# %pwd
# Out:
# 'C:\\Users\\USER\\Google 드라이브\\_데잇걸즈\\Titanic'
